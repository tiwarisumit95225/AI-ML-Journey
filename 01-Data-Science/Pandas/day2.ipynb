# %% [markdown]
# # Accessing data with pandas

# %%
import pandas as pd

# %%
coffee=pd.read_csv('./data/coffee.csv')

# %%
coffee.head(10)
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
# 5  Wednesday       Latte          25
# 6   Thursday    Espresso          40
# 7   Thursday       Latte          30
# 8     Friday    Espresso          45
# 9     Friday       Latte          35

# %%
display(coffee)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.sample(10)
# Out:
#           Day Coffee Type  Units Sold
# 9      Friday       Latte          35
# 3     Tuesday       Latte          20
# 5   Wednesday       Latte          25
# 7    Thursday       Latte          30
# 10   Saturday    Espresso          45
# 13     Sunday       Latte          35
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 11   Saturday       Latte          35
# 1      Monday       Latte          15

# %%
coffee.loc[2]
# Out:
# Day             Tuesday
# Coffee Type    Espresso
# Units Sold           30
# Name: 2, dtype: object

# %%
coffee.loc[[0,1,2]]
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          15
# 2  Tuesday    Espresso          30

# %%
coffee.loc[0:5,["Day","Coffee Type"]]
# Out:
#          Day Coffee Type
# 0     Monday    Espresso
# 1     Monday       Latte
# 2    Tuesday    Espresso
# 3    Tuesday       Latte
# 4  Wednesday    Espresso
# 5  Wednesday       Latte

# %%
coffee.iloc[0:5,[0,2]] #only let element  access by index.
# Out:
#          Day  Units Sold
# 0     Monday          25
# 1     Monday          15
# 2    Tuesday          30
# 3    Tuesday          20
# 4  Wednesday          35

# %%
coffee.index=coffee["Day"]

# %%
coffee
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          15
# Tuesday      Tuesday    Espresso          30
# Tuesday      Tuesday       Latte          20
# Wednesday  Wednesday    Espresso          35
# Wednesday  Wednesday       Latte          25
# Thursday    Thursday    Espresso          40
# Thursday    Thursday       Latte          30
# Friday        Friday    Espresso          45
# Friday        Friday       Latte          35
# Saturday    Saturday    Espresso          45
# Saturday    Saturday       Latte          35
# Sunday        Sunday    Espresso          45
# Sunday        Sunday       Latte          35

# %%
coffee.loc["Monday"]
# Out:
#            Day Coffee Type  Units Sold
# Day
# Monday  Monday    Espresso          25
# Monday  Monday       Latte          15

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.loc[1,["Units Sold"]]=10

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          10
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.at[2,"Day"]
# Out:
# 'Tuesday'

# %%
coffee.iat[0,2]
# Out:
# np.int64(25)

# %%
coffee.sort_values(["Units Sold","Coffee Type"],ascending=[0,1])
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          10

# %% [markdown]
# ### Filtering Data

# %%
bios=pd.read_csv('./data/bios.csv')

# %%
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 0       1960-10-02
# 1              NaN
# 2       1994-07-17
# 3       1978-03-20
# 4       1930-07-25
# ...            ...
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20
#
# [145500 rows x 10 columns]

# %%
bios.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  str
#  2   born_date     143693 non-null  str
#  3   born_city     110908 non-null  str
#  4   born_region   110908 non-null  str
#  5   born_country  110908 non-null  str
#  6   NOC           145499 non-null  str
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   str
# dtypes: float64(2), int64(1), str(7)
# memory usage: 18.5 MB

# %%
bios.loc[bios['height_cm']>215,["name","height_cm"]]
# Out:
#                          name  height_cm
# 5089       Viktor Pankrashkin      220.0
# 5583     Paulinho Villas Boas      217.0
# 5673           Gunther Behnke      221.0
# 5716                 Uwe Blab      218.0
# 5781           Tommy Burleson      223.0
# 5796            Andy Campbell      218.0
# 6223              Lars Hansen      216.0
# 6270              Hu Zhangbao      216.0
# 6409         Sergey Kovalenko      216.0
# 6420            Jānis Krūmiņš      218.0
# 6504              Luc Longley      220.0
# 6722         Shaquille O'Neal      216.0
# 6937           David Robinson      216.0
# 6978          Arvydas Sabonis      223.0
# 7074           Paulo da Silva      217.0
# 7188       Vladimir Tkachenko      220.0
# 7281         Stojko Vranković      217.0
# 7376      Eurelijus Žukauskas      218.0
# 52608         Aleksey Kazakov      217.0
# 82100           Frédéric Weis      218.0
# 89070                Yao Ming      226.0
# 89075          Roberto Dueñas      221.0
# 107408       Peter John Ramos      219.0
# 112312           Stanko Barać      217.0
# 112332    Andreas Glyniadakis      216.0
# 112337          Hamed Haddadi      218.0
# 118663         Timofey Mozgov      216.0
# 118676        Dmitry Musersky      219.0
# 120266           Zhang Zhaoxu      221.0
# 121694            Salah Mejri      216.0
# 123850         Tyson Chandler      216.0
# 130460               Li Muhao      218.0
# 130461                Zhou Qi      217.0
# 138671          Ondřej Balvín      216.0
# 139365         Moustapha Fall      218.0

# %%
bios[(bios['height_cm']>180)&(bios["NOC"]=="India")][["name","height_cm"]]
# Out:
#                    name  height_cm
# 274      Anand Amritraj      185.0
# 275      Vijay Amritraj      193.0
# 276       Chetan Baboor      188.0
# 278     Mahesh Bhupathi      185.0
# 284         Vimal Kumar      184.0
# ...                 ...        ...
# 131641    Hardeep Singh      183.0
# 140263     Satish Kumar      188.0
# 140265      Udayan Mane      192.0
# 140268    Gurjant Singh      183.0
# 140276     Arvind Singh      184.0
#
# [89 rows x 2 columns]

# %%
bios[bios["name"].str.contains("Neeraj",case=False)]
# Out:
#         athlete_id           name   born_date born_city born_region  \
# 140251      143754  Neeraj Chopra  1997-12-24       NaN         NaN
#
#        born_country    NOC  height_cm  weight_kg died_date
# 140251          NaN  India        NaN        NaN       NaN

# %%
bios[bios['born_country'].isin(["USA","IND"]) & (bios['name'].str.startswith("Sumit"))]
# Out:
#         athlete_id           name   born_date born_city born_region  \
# 120558      122483  Sumit Sangwan  1993-01-01    Sohana      Punjab
# 143996      147660    Sumit Nagal  1997-08-16   Jhajjar     Haryana
#
#        born_country    NOC  height_cm  weight_kg died_date
# 120558          IND  India        NaN        NaN       NaN
# 143996          IND  India        NaN        NaN       NaN

# %%
bios.query('born_country=="India" and name=="Sumit"')
# Out:
# Empty DataFrame
# Columns: [athlete_id, name, born_date, born_city, born_region, born_country, NOC, height_cm, weight_kg, died_date]
# Index: []

# %% [markdown]
# ### Adding/Removing Columns from dataframe

# %%
coffee['Price']=5.99

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  Price
# 0      Monday    Espresso          25       3.99   5.99
# 1      Monday       Latte          15       6.33   5.99
# 2     Tuesday    Espresso          30       3.99   5.99
# 3     Tuesday       Latte          20       6.33   5.99
# 4   Wednesday    Espresso          35       3.99   5.99
# 5   Wednesday       Latte          25       6.33   5.99
# 6    Thursday    Espresso          40       3.99   5.99
# 7    Thursday       Latte          30       6.33   5.99
# 8      Friday    Espresso          45       3.99   5.99
# 9      Friday       Latte          35       6.33   5.99
# 10   Saturday    Espresso          45       3.99   5.99
# 11   Saturday       Latte          35       6.33   5.99
# 12     Sunday    Espresso          45       3.99   5.99
# 13     Sunday       Latte          35       6.33   5.99

# %%
import numpy as np

coffee['new_price']=np.where(coffee['Coffee Type']=='Espresso',3.99,6.33)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  Price
# 0      Monday    Espresso          25       3.99   5.99
# 1      Monday       Latte          15       6.33   5.99
# 2     Tuesday    Espresso          30       3.99   5.99
# 3     Tuesday       Latte          20       6.33   5.99
# 4   Wednesday    Espresso          35       3.99   5.99
# 5   Wednesday       Latte          25       6.33   5.99
# 6    Thursday    Espresso          40       3.99   5.99
# 7    Thursday       Latte          30       6.33   5.99
# 8      Friday    Espresso          45       3.99   5.99
# 9      Friday       Latte          35       6.33   5.99
# 10   Saturday    Espresso          45       3.99   5.99
# 11   Saturday       Latte          35       6.33   5.99
# 12     Sunday    Espresso          45       3.99   5.99
# 13     Sunday       Latte          35       6.33   5.99

# %%
coffee.drop(columns="Price" ,inplace=True)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          25       3.99
# 1      Monday       Latte          15       6.33
# 2     Tuesday    Espresso          30       3.99
# 3     Tuesday       Latte          20       6.33
# 4   Wednesday    Espresso          35       3.99
# 5   Wednesday       Latte          25       6.33
# 6    Thursday    Espresso          40       3.99
# 7    Thursday       Latte          30       6.33
# 8      Friday    Espresso          45       3.99
# 9      Friday       Latte          35       6.33
# 10   Saturday    Espresso          45       3.99
# 11   Saturday       Latte          35       6.33
# 12     Sunday    Espresso          45       3.99
# 13     Sunday       Latte          35       6.33

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          25       3.99
# 1      Monday       Latte          15       6.33
# 2     Tuesday    Espresso          30       3.99
# 3     Tuesday       Latte          20       6.33
# 4   Wednesday    Espresso          35       3.99
# 5   Wednesday       Latte          25       6.33
# 6    Thursday    Espresso          40       3.99
# 7    Thursday       Latte          30       6.33
# 8      Friday    Espresso          45       3.99
# 9      Friday       Latte          35       6.33
# 10   Saturday    Espresso          45       3.99
# 11   Saturday       Latte          35       6.33
# 12     Sunday    Espresso          45       3.99
# 13     Sunday       Latte          35       6.33

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          25       3.99
# 1      Monday       Latte          15       6.33
# 2     Tuesday    Espresso          30       3.99
# 3     Tuesday       Latte          20       6.33
# 4   Wednesday    Espresso          35       3.99
# 5   Wednesday       Latte          25       6.33
# 6    Thursday    Espresso          40       3.99
# 7    Thursday       Latte          30       6.33
# 8      Friday    Espresso          45       3.99
# 9      Friday       Latte          35       6.33
# 10   Saturday    Espresso          45       3.99
# 11   Saturday       Latte          35       6.33
# 12     Sunday    Espresso          45       3.99
# 13     Sunday       Latte          35       6.33

# %%
coffee['revenue']=coffee['new_price']*coffee["Units Sold"]

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  revenue
# 0      Monday    Espresso          25       3.99    99.75
# 1      Monday       Latte          15       6.33    94.95
# 2     Tuesday    Espresso          30       3.99   119.70
# 3     Tuesday       Latte          20       6.33   126.60
# 4   Wednesday    Espresso          35       3.99   139.65
# 5   Wednesday       Latte          25       6.33   158.25
# 6    Thursday    Espresso          40       3.99   159.60
# 7    Thursday       Latte          30       6.33   189.90
# 8      Friday    Espresso          45       3.99   179.55
# 9      Friday       Latte          35       6.33   221.55
# 10   Saturday    Espresso          45       3.99   179.55
# 11   Saturday       Latte          35       6.33   221.55
# 12     Sunday    Espresso          45       3.99   179.55
# 13     Sunday       Latte          35       6.33   221.55

# %%
coffee=coffee.rename(columns={'new_price':"price"})

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso          25   3.99    99.75
# 1      Monday       Latte          15   6.33    94.95
# 2     Tuesday    Espresso          30   3.99   119.70
# 3     Tuesday       Latte          20   6.33   126.60
# 4   Wednesday    Espresso          35   3.99   139.65
# 5   Wednesday       Latte          25   6.33   158.25
# 6    Thursday    Espresso          40   3.99   159.60
# 7    Thursday       Latte          30   6.33   189.90
# 8      Friday    Espresso          45   3.99   179.55
# 9      Friday       Latte          35   6.33   221.55
# 10   Saturday    Espresso          45   3.99   179.55
# 11   Saturday       Latte          35   6.33   221.55
# 12     Sunday    Espresso          45   3.99   179.55
# 13     Sunday       Latte          35   6.33   221.55

# %%
bios_new=bios.copy()

# %%
bios_new['first_name']=bios_new['name'].str.split(' ').str[0]

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date     first_name
# 0       1960-10-02  Jean-François
# 1              NaN         Arnaud
# 2       1994-07-17           Jean
# 3       1978-03-20        Jacques
# 4       1930-07-25         Albert
# ...            ...            ...
# 145495         NaN         Polina
# 145496         NaN       Valeriya
# 145497         NaN         Yuliya
# 145498  1986-03-18          André
# 145499  2003-10-20           Bill
#
# [145500 rows x 11 columns]
